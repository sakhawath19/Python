# %%
# https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots
# https://matplotlib.org/3.1.0/tutorials/intermediate/gridspec.html
# use gridspec when you need different size of subplot in the same figure 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
plt.style.use('seaborn')

# %%
# it creates one figure and 4 axis or 4 plot
fig, ax = plt.subplots(nrows=2, ncols=2, constrained_layout=True)  # constrained_layout to avoid overlapping axis
print(ax)
ax[0][0].set_title('first one')
ax[0][1].set_title('first row second one')
ax[1][0].set_title('second row first one')
ax[1][1].set_title('second row second plot')
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCA8EC7D08>
# ...
# Text(0.5, 1.0, 'second row second plot')

# %%
# unpacking plot
# one figure contains two plots
# fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

# One figure contains four plots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, constrained_layout=True)

print(ax1)
print(ax2)
# Out:
# AxesSubplot(0.125,0.536818;0.352273x0.343182)
# AxesSubplot(0.547727,0.536818;0.352273x0.343182)

# %%
# unpacking plot with different figures

fig1, ax1 = plt.subplots()

# fig1.set_figheight(4)                        
# fig1.set_figwidth(4)
fig1.set_size_inches(5, 3)

ax1.set_title('This is plotted in first figure')
# Out:
# Text(0.5, 1.0, 'This is plotted in first figure')

# %%
fig2, (ax2, ax3) = plt.subplots(nrows=2, ncols=1, figsize=(5,3), constrained_layout=True)

ax2.set_title('This is plotted in second figure')
ax2.set_ylabel('Y grid')
ax3.set_xlabel('X grid')
# Out:
# Text(0.5, 0, 'X grid')

# %%
# Adding subplot later
f = plt.figure(figsize=(10,3))

ax1 = f.add_subplot(121)
ax2 = f.add_subplot(122)

# %%
# object oriented style plotting

x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig, axs = plt.subplots(2, 2, constrained_layout=True)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0,0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0,1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1,0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1,1]')

plt.tight_layout()
plt.show()

# fig1.savefig('fig1.png')
# fig2.savefig('fig2.png')
# Out:
# C:\Users\Sakhawath Hossain\Anaconda3\envs\CPU_3.7.5\lib\site-packages\ipykernel_launcher.py:16: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   app.launch_new_instance()

# %%
# normal style plotting

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x, y)
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# %%
# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')
# Out:
# (<Figure size 576x396 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCAA64ED08>,
# ...
#        dtype=object))

# %%
# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')
# Out:
# (<Figure size 576x396 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCAA64F208>,
# ...
#        dtype=object))

# %%
# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')
# Out:
# (<Figure size 576x396 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCAA875688>,
# ...
#        dtype=object))

# %%
# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)
# Out:
# (<Figure size 576x396 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCAA7AA388>,
# ...
#        dtype=object))

# %%
# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)

# %%
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0,0]')

axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0,1]')

axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1,0]')

axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1,1]')
# Out:
# Text(0.5, 1.0, 'Axis [1,1]')

# %%
fig3 = plt.figure(figsize=(10, 8), constrained_layout=True)
gs = fig3.add_gridspec(3, 3)

f3_ax1 = fig3.add_subplot(gs[0, :])
f3_ax1.set_title('gs[0, :]')

f3_ax2 = fig3.add_subplot(gs[1, :-1])
f3_ax2.set_title('gs[1, :-1]')

f3_ax3 = fig3.add_subplot(gs[1:, -1])
f3_ax3.set_title('gs[1:, -1]')

f3_ax4 = fig3.add_subplot(gs[-1, 0])
f3_ax4.set_title('gs[-1, 0]')

f3_ax5 = fig3.add_subplot(gs[-1, -2])
f3_ax5.set_title('gs[-1, -2]')
# Out:
# Text(0.5, 1.0, 'gs[-1, -2]')

# %%
fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(3, 3)

f3_ax1 = fig3.add_subplot(gs[0, :])
f3_ax1.set_title('gs[0, :]')

f3_ax2 = fig3.add_subplot(gs[1, :-1])
f3_ax2.set_title('gs[1, :-1]')

f3_ax3 = fig3.add_subplot(gs[1:3, 2])
f3_ax3.set_title('gs[1:, -1]')

f3_ax4 = fig3.add_subplot(gs[-1, 0])
f3_ax4.set_title('gs[-1, 0]')

f3_ax5 = fig3.add_subplot(gs[-1, -2])
f3_ax5.set_title('gs[-1, -2]')
# Out:
# Text(0.5, 1.0, 'gs[-1, -2]')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = fig.add_gridspec(4, 4, hspace=0.2, wspace=0.2)

main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()
