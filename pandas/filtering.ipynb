# %%
import pandas as pd 

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

df = pd.read_csv('./data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('./data/survey_results_schema.csv', index_col='Column')

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary].head(2)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 6                                Never
# 9           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 6           The quality of OSS and closed source software ...
# 9           The quality of OSS and closed source software ...
#
#                     Employment      Country Student  \
# Respondent
# 6           Employed full-time       Canada      No
# 9           Employed full-time  New Zealand      No
#
#                                                       EdLevel  \
# Respondent
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
#
# ...

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']].head(2)
# Out:
#                 Country                                 LanguageWorkedWith  \
# Respondent
# 6                Canada                                         Java;R;SQL
# 9           New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
#
#             ConvertedComp
# Respondent
# 6                366420.0
# 9                 95179.0

# %%
df.loc[[1, 2], ['Country', 'LanguageWorkedWith']]
# Out:
#                            Country               LanguageWorkedWith
# Respondent
# 1                   United Kingdom  HTML/CSS;Java;JavaScript;Python
# 2           Bosnia and Herzegovina              C++;HTML/CSS;Python

# %%
df.loc[1:3, 'Country': 'LanguageWorkedWith']
# Out:
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                            UndergradMajor  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           Web development or web design
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
#
# ...

# %%
### Use of isin to avoid long filter command 
countries = ['United states', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# df.loc[filt, 'Country'].value_counts()
# Out:
# India             9061
# Germany           5866
# United Kingdom    5737
# Canada            3395
# Name: Country, dtype: int64

# %%
### filter rows with specific string

filt = df['LanguageWorkedWith'].str.contains('Python', na=False) # na=False will ignore nan values
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
### LEARN string methods in pandas
