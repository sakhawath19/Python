# %%
import pandas as pd 

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

df = pd.read_csv('./data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('./data/survey_results_schema.csv', index_col='Column')

df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %% [markdown]
# # Aggregation:
# #### combining multiple pieces of data into a single result

# %%
df['ConvertedComp'].head(50)
# Out:
# Respondent
# 1           NaN
# 2           NaN
# 3        8820.0
# 4       61000.0
# 5           NaN
# 6      366420.0
# 7           NaN
# 8           NaN
# 9       95179.0
# 10      13293.0
# 11          NaN
# 12          NaN
# 13      90000.0
# 14      57060.0
# 15          NaN
# 16     455352.0
# 17      65277.0
# 18      21996.0
# 19      31140.0
# 20      41244.0
# 21          NaN
# 22     103000.0
# 23      69000.0
# 24      26388.0
# 25       6300.0
# 26     114000.0
# 27          NaN
# 28          NaN
# 29     100000.0
# 30      90417.0
# 31          NaN
# 32    1100000.0
# 33       8400.0
# 34          NaN
# 35      80000.0
# 36      20628.0
# 37          NaN
# 38      51312.0
# 39     156000.0
# 40          NaN
# 41          NaN
# 42          NaN
# 43      20623.0
# 44      87996.0
# 45     175000.0
# 46          NaN
# 47     187000.0
# 48          NaN
# 49      60000.0
# 50       5597.0
# Name: ConvertedComp, dtype: float64

# %%
# To see the median of the salary need to run median method in salary series
# Let see median salary broken by the country ???? use grouping

df['ConvertedComp'].median()               # ignored na values
# Out:
# 57287.0

# %%
# To see median values of all the columns that have number 
df.median()
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
# It gives more mathematical analysis
# Mean is heavily biased by the high salary, so it may give unexpected results 
# In that case it is better to look at median 
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()             # How many people answered the question
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()           # How many people answered yes and how many people answered no in that series
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']                # To know what question was asked in survey
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()            # What is popular social media developer used
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
# Social media popularity lot depends on country
# It is good to know which social media is popular in different country; Need to use grouping???

df['SocialMedia'].value_counts(normalize=True)             # its broken down to percentage
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %% [markdown]
# # Grouping
# #### Split----Apply function----Combine results

# %%
df['Country'].value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Dominica                     1
# Timor-Leste                  1
# Brunei Darussalam            1
# Niger                        1
# Saint Kitts and Nevis        1
# Name: Country, Length: 179, dtype: int64

# %%
df.groupby(['Country'])                     # it returns a DataFrameGroupBy object which contains several groups

# %%
# let assign that object into a variable 
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# ...

# %%
# Result from one country can be extracted by filter as well

filt = (df['Country'] == 'United States')

df.loc[filt]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# ...

# %%
df.loc[filt, 'SocialMedia'].value_counts()             # Results for united states only
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)         # it returns multiple index in the series like country and SocialMedia
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['United States']   # Do not need to run filter for every country
# Out:
# SocialMedia
# Reddit                      0.284346
# Twitter                     0.173002
# Facebook                    0.141874
# YouTube                     0.122867
# I don't use social media    0.092338
# Instagram                   0.082410
# LinkedIn                    0.050883
# WhatsApp                    0.030380
# Snapchat                    0.016263
# WeChat 微信                   0.004639
# VK ВКонта́кте               0.000449
# Weibo 新浪微博                  0.000399
# Hello                       0.000100
# Youku Tudou 优酷              0.000050
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median()             # median salaries by country
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].median().loc['Finland']
# Out:
# 55569.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])     # multiple aggregate function produce results
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = (df['Country'] == 'India')

# df.loc[filt]['LanguageWorkedWith']
df.loc[filt, 'LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 8         True
# 10        True
# 15       False
# 50        True
# 65       False
#          ...
# 77339    False
# 79795     True
# 83862    False
# 84299     True
# 86012    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
df.loc[filt, 'LanguageWorkedWith'].str.contains('Python').sum()          # how many people using python in india
# Out:
# 3105

# %%
df.loc[filt, 'LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum() # showed error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-de20bc3e2dcf> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum() # showed error
#
# ~\Anaconda3\envs\CPU_3.7.5\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
# lamda function takes series as an input
# So respondent from each country it takes as an input

country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts(normalize=True))
# Out:
# Country
# Afghanistan  False    0.794872
#              True     0.205128
# Albania      False    0.722892
#              True     0.277108
# Algeria      False    0.682540
#                         ...
# Yemen        True     0.176471
# Zambia       False    0.666667
#              True     0.333333
# Zimbabwe     False    0.641026
#              True     0.358974
# Name: LanguageWorkedWith, Length: 335, dtype: float64

# %%
country_grp['LanguageWorkedWith'].value_counts()
# Out:
# Country      LanguageWorkedWith
# Afghanistan  HTML/CSS;JavaScript;PHP;SQL                3
#              HTML/CSS;Java;JavaScript;PHP;Python;SQL    2
#              HTML/CSS;Java;PHP;SQL                      2
#              Python                                     2
#              Assembly                                   1
#                                                        ..
# Zimbabwe     HTML/CSS;Python;SQL                        1
#              Java;JavaScript;Kotlin;Python              1
#              Java;JavaScript;SQL                        1
#              Objective-C                                1
#              Python                                     1
# Name: LanguageWorkedWith, Length: 48114, dtype: int64

# %%
country_respondents = df['Country'].value_counts() 
country_respondents
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Dominica                     1
# Timor-Leste                  1
# Brunei Darussalam            1
# Niger                        1
# Saint Kitts and Nevis        1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')
python_df
# Out:
#                        Country  LanguageWorkedWith
# United States            20949               10083
# India                     9061                3105
# Germany                   5866                2451
# United Kingdom            5737                2384
# Canada                    3395                1558
# ...                        ...                 ...
# Dominica                     1                   1
# Timor-Leste                  1                   1
# Brunei Darussalam            1                   0
# Niger                        1                   1
# Saint Kitts and Nevis        1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                        NumRespondents  NumKnowsPython
# United States                   20949           10083
# India                            9061            3105
# Germany                          5866            2451
# United Kingdom                   5737            2384
# Canada                           3395            1558
# ...                               ...             ...
# Dominica                            1               1
# Timor-Leste                         1               1
# Brunei Darussalam                   1               0
# Niger                               1               1
# Saint Kitts and Nevis               1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'] * 100)

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Sao Tome and Principe                          1               1
# Niger                                          1               1
# Timor-Leste                                    1               1
# Dominica                                       1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Guinea                                         3               2
# Bahamas                                        3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Benin                                          5               3
# Haiti                                          5               3
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64
